# %% [markdown]
# # Mushroom Decision Tree (Reduced Features) — Student Exercise
# ## Your Name:
# ## Date:
# ### In Blackboard you will submit your Github URL after saving your notebook to your class repository, AND a PDF of this notebook (in Colab, File . . . Print . . . PDF)
# This activity uses a simplified version of the Mushroom dataset to create a decision tree.
#
# ## Goals
# - Build a decision tree classifier
# - Interpret a confusion matrix and accuracy
# - Explain what the root and first-level nodes mean
# - Translate tree splits into plain English

# %% [markdown]
# ## 1️⃣ Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ## 2️⃣ Load the Mushroom dataset (code is completed for you)
# **Target:** `class`
# - `e` = edible which becomes 0 or not poisonous
# - `p` = poisonous which becomes 1

# %%
#note feature names, we will reduce these
mush = fetch_openml('mushroom', version=1, as_frame=True)
df = mush.frame.copy()
# rename the column
df = df.rename(columns={"bruises%3F": "bruises"})
df.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-color-above-ring  \
# 0         n          k           e  ...                      w
# 1         b          k           e  ...                      w
# 2         b          n           e  ...                      w
# 3         n          n           e  ...                      w
# 4         b          k           t  ...                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# ...

# %% [markdown]
# ## 3️⃣ Use a reduced feature set (code is completed for you)
# These features are highly predictive and keep the tree readable. Note the class is mapped to 0 (edible) and 1 (poisonous).

# %%
features = ['odor', 'spore-print-color', 'gill-size', 'gill-color', 'bruises']

X = df[features]
y = df['class'].map({'e':0, 'p':1})

X.head(), y.value_counts()
# Out:
# (  odor spore-print-color gill-size gill-color bruises
#  0    p                 k         n          k       t
#  1    a                 n         b          k       t
#  2    l                 n         b          n       t
#  3    p                 k         n          n       t
#  4    n                 n         b          k       f,
#  class
#  0    4208
#  1    3916
#  Name: count, dtype: int64)

# %% [markdown]
# ## 4️⃣ One‑hot encode the categorical features (Add Code)
# Each category becomes a YES/NO column.

# %%
X = pd.get_dummies(X, columns=['odor', 'spore-print-color', 'gill-size', 'gill-color', 'bruises'], prefix_sep=" = ")
X.head()
# Out:
#    odor = a  odor = c  odor = f  odor = l  odor = m  odor = n  odor = p  \
# 0     False     False     False     False     False     False      True
# 1      True     False     False     False     False     False     False
# 2     False     False     False      True     False     False     False
# 3     False     False     False     False     False     False      True
# 4     False     False     False     False     False      True     False
#
#    odor = s  odor = y  spore-print-color = b  ...  gill-color = k  \
# 0     False     False                  False  ...            True
# 1     False     False                  False  ...            True
# 2     False     False                  False  ...           False
# 3     False     False                  False  ...           False
# 4     False     False                  False  ...            True
#
#    gill-color = n  gill-color = o  gill-color = p  gill-color = r  \
# ...

# %% [markdown]
# ## 5️⃣ Train/test split (Add Code)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# %% [markdown]
# ## 6️⃣ Train a small decision tree (Add Code)

# %%
model = DecisionTreeClassifier(max_depth=3, random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %% [markdown]
# ## 7️⃣ Evaluate the model (Add Code)

# %%
pred = model.predict(X_test)

print("Accuracy:", round(accuracy_score(y_test, pred), 3))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, pred))
print("\nClassification Report:\n", classification_report(y_test, pred))
# Out:
# Accuracy: 0.959
#
# Confusion Matrix:
#  [[1052    0]
#  [  83  896]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      1052
#            1       1.00      0.92      0.96       979
#
#     accuracy                           0.96      2031
#    macro avg       0.96      0.96      0.96      2031
# weighted avg       0.96      0.96      0.96      2031

# %% [markdown]
# ## 8️⃣ Visualize the decision tree (Add Code)

# %%
df.value_counts("odor")

plt.figure(figsize=(16,9))
plot_tree(model, feature_names=X.columns, class_names=['odor', 'spore-print-color', 'gill-size', 'gill-color', 'bruises'], filled=True)
plt.title("Mushroom Decision Tree")
plt. show()

# %% [markdown]
# ## 9️⃣ Print IF–THEN rules (Add Code)

# %%
print(export_text(model, feature_names=list(X.columns)))
# Out:
# |--- odor = n <= 0.50
# |   |--- bruises = t <= 0.50
# |   |   |--- class: 1
# |   |--- bruises = t >  0.50
# |   |   |--- spore-print-color = h <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- spore-print-color = h >  0.50
# |   |   |   |--- class: 1
# |--- odor = n >  0.50
# |   |--- spore-print-color = r <= 0.50
# |   |   |--- gill-size = n <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- gill-size = n >  0.50
# |   |   |   |--- class: 0
# |   |--- spore-print-color = r >  0.50
# |   |   |--- class: 1

# %% [markdown]
# ---
# # QUESTIONS TO ANSWER (provide answers in markdown)
# ### Confusion Matrix & Accuracy
# 1. What was the model accuracy? - 0.96, fairly high I believe.
# 2. How many poisonous mushrooms were correctly classified? 1052 it seems.
# 3. How many poisonous mushrooms were incorrectly predicted as edible? 0, oddly enough. It seems it's errors were solely false negatives.
# 4. Why is misclassifying a poisonous mushroom more serious than misclassifying an edible one? Someone would perish or be poisoned for sure.
#
# ### Understanding the Tree
# 5. What feature appears at the **root node**? Odor.
# 6. What question is the root node asking in plain English? If Odor <= 0 .5 is true, go left, Else go right.
# 7. Describe what the **left branch** and **right branch** mean. If the root statement is true, or false respectively.
#
# ### First Level Nodes
# 8. Look at the two nodes directly below the root.
#    - What feature does each split on? - Odor and spore-print-color respectively.
#    - What question is each node asking? Essentially, if the precise mixture of these features is less than or equal to 0.5.
#    - What does following the left vs right branch mean? Two branches breaking down oder granularities, and then using other features to determine if the mushroom is poisonous or not.
#
# ### Interpretation
# 9. Choose ONE full path from the root to a leaf and translate it into plain English. If Odor <= 0 .5 is true, go left. If bruises < 0.5 is true, go left. Decision terminates, presumed true.
# 10. Based on the tree, what feature seems most important for predicting if a mushroom is poisonous? - Odor, it seeems.
#
# ### Exploration
# 11. Change `max_depth` to 2. What changed? - The accuracy was slightly increased, and the decision tree was flattened.
# 12. Change `max_depth` to 5. What changed? - The accuracy was moderately increased, and the decision tree's noders were made more granular.
